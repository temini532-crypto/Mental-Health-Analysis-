# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %%
Bike_sales= pd.read_csv('Bike_Sales_Sort_Lab_4.1.2.csv')

# %%
Bike_sales.head(4)
# Out:
#                Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0  2-September-2015    2  September  2015            29  Young Adults (25-34)
# 1   22-January-2014   22    January  2014            29  Young Adults (25-34)
# 2   22-January-2016   22    January  2016            29  Young Adults (25-34)
# 3    25-August-2015   25     August  2015            49        Adults (35-64)
#
#   Customer_Gender Country             State Product_Category Sub_Category  \
# 0               M  Canada  British Columbia      Accessories   Bike Racks
# 1               M  Canada  British Columbia      Accessories   Bike Racks
# 2               M  Canada  British Columbia      Accessories   Bike Racks
# 3               M  Canada  British Columbia      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               1         45         120      74    45
# ...

# %%
Bike_sales['Customer_Age'].max() - Bike_sales['Customer_Age'].min()
# Out:
# 42

# %%
Bike_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              69 non-null     object
#  1   Day               69 non-null     int64
#  2   Month             69 non-null     object
#  3   Year              69 non-null     int64
#  4   Customer_Age      69 non-null     int64
#  5   Age_Group         69 non-null     object
#  6   Customer_Gender   69 non-null     object
#  7   Country           69 non-null     object
#  8   State             69 non-null     object
#  9   Product_Category  69 non-null     object
#  10  Sub_Category      69 non-null     object
#  11  Product           69 non-null     object
#  12  Order_Quantity    69 non-null     int64
#  13  Unit_Cost         69 non-null     int64
#  14  Unit_Price        69 non-null     int64
#  15  Profit            69 non-null     int64
# ...

# %%
Bike_sales['Unit_Cost'].sum()
# Out:
# np.int64(3105)

# %%
Bike_sales['Revenue'].sum()
# Out:
# np.int64(71318)

# %%
Bike_sales['Profit'].sum()
# Out:
# np.int64(42338)

# %%
Bike_sales.describe()
# Out:
#              Day         Year  Customer_Age  Order_Quantity  Unit_Cost  \
# count  69.000000    69.000000     69.000000       69.000000       69.0
# mean   18.826087  2014.318841     37.927536        9.333333       45.0
# std     8.385836     1.104706     10.942791        7.267305        0.0
# min     2.000000  2013.000000     19.000000        1.000000       45.0
# 25%    15.000000  2013.000000     29.000000        4.000000       45.0
# 50%    19.000000  2014.000000     35.000000        8.000000       45.0
# 75%    26.000000  2015.000000     48.000000       11.000000       45.0
# max    31.000000  2016.000000     61.000000       28.000000       45.0
#
#        Unit_Price       Profit         Cost      Revenue
# count        69.0    69.000000    69.000000    69.000000
# mean        120.0   613.594203   420.000000  1033.594203
# std           0.0   490.591399   327.028736   813.051755
# min         120.0    53.000000    45.000000    98.000000
# ...

# %%
Bike_sales.isnull()
# Out:
#      Date    Day  Month   Year  Customer_Age  Age_Group  Customer_Gender  \
# 0   False  False  False  False         False      False            False
# 1   False  False  False  False         False      False            False
# 2   False  False  False  False         False      False            False
# 3   False  False  False  False         False      False            False
# 4   False  False  False  False         False      False            False
# ..    ...    ...    ...    ...           ...        ...              ...
# 64  False  False  False  False         False      False            False
# 65  False  False  False  False         False      False            False
# 66  False  False  False  False         False      False            False
# 67  False  False  False  False         False      False            False
# 68  False  False  False  False         False      False            False
#
#     Country  State  Product_Category  Sub_Category  Product  Order_Quantity  \
# ...

# %%
Bike_sales.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
Bike_sales.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# Length: 69, dtype: bool

# %%
Bike_sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
Salesinyear2015 = Bike_sales.query('Year == 2015')
Salesinyear2015.head(10)
# Out:
#                  Date  Day      Month  Year  Customer_Age  \
# 0    2-September-2015    2  September  2015            29
# 3      25-August-2015   25     August  2015            49
# 4      27-August-2015   27     August  2015            57
# 5       7-August-2015    7     August  2015            38
# 7       3-August-2015    3     August  2015            35
# 13  24-September-2015   24  September  2015            32
# 20   26-December-2015   26   December  2015            49
# 23       17-July-2015   17       July  2015            24
# 28       15-July-2015   15       July  2015            34
# 29      2-August-2015    2     August  2015            29
#
#                Age_Group Customer_Gender    Country             State  \
# 0   Young Adults (25-34)               M     Canada  British Columbia
# 3         Adults (35-64)               M     Canada  British Columbia
# 4         Adults (35-64)               M     Canada  British Columbia
# ...

# %%
Salesinyear2014 = Bike_sales.query('Year == 2014')

# %%
plt.Figure(figsize=(6,4))
plt.scatter(Salesinyear2015['Age_Group'],Salesinyear2015['Cost'])
plt.show()

# %%
Costin2015= Salesinyear2015.query('Age_Group == "Young Adults (25-34)"')
print('Average Cost In 2015 for Young adult:', Costin2015['Cost'].mean())
Costin2015= Salesinyear2015.query('Age_Group == "Adults (35-64)"')
print('Average Cost In 2015 for adult:', Costin2015['Cost'].mean())
Costin2015= Salesinyear2015.query('Age_Group == "Youth (<25)"')
print('Average Cost In 2015 for Youth Under twenty five :', Costin2015['Cost'].mean())
# Out:
# Average Cost In 2015 for Young adult: 427.5
# Average Cost In 2015 for adult: 320.0
# Average Cost In 2015 for Youth Under twenty five : 326.25

# %%
plt.figure(figsize=(6,4))
plt.bar(Costin2015['Cost'].mean(),)
# Out:
#   Cell In[19], line 1
#     Bike_sales.
#                ^
# SyntaxError: invalid syntax
